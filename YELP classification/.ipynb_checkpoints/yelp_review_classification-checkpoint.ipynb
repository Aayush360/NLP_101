# %%
import numpy as np
import pandas as pd

from collections import Counter

import re

# %%
df = pd.read_csv('dataset/reviews.csv')

# %%
df.head()
# Out:
#      rating                                             review
# 0  negative  terrible place to work for i just heard a stor...
# 1  negative   hours , minutes total time for an extremely s...
# 2  negative  my less than stellar review is for service . w...
# 3  negative  i m granting one star because there s no way t...
# 4  negative  the food here is mediocre at best . i went aft...

# %%
df.tail()
# Out:
#          rating                                             review
# 55995  positive  great food . wonderful , friendly service . i ...
# 55996  positive  charlotte should be the new standard for moder...
# 55997  positive  get the encore sandwich ! ! make sure to get i...
# 55998  positive  i m a pretty big ice cream gelato fan . pretty...
# 55999  positive  where else can you find all the parts and piec...

# %%
vocab={}

# %%
def initVocab():
    unkToken = '<UNK>'
    vocab['t_2_i']={} #vocab for index to token
    vocab['i_2_t']={} #vocab for token to index
    vocab['unkToken']=unkToken
    idx = addToken(unkToken) # helps to add token to the dict/vocab as we go through the data, should only add unique token
    vocab['unkTokenIdx'] = idx

# %%
def addToken(token):
    if token in vocab['t_2_i']:
        idx = vocab['t_2_i'][token]
    else:
        idx = len(vocab['t_2_i'])
        vocab['t_2_i'][token]=idx
        vocab['i_2_t'][idx]=token
        
    return idx

# %%
def addManyTokens(tokens):
    ''' tokens: list of words
    returns indices of the list of words
    '''
    idxs = [addToken(token) for token in tokens]
    return idxs

# %%
def lookUpToken(token):
    '''given the token, it returns the index for that token'''
    if vocab['unkTokenIdx']>=0:
        return vocab['t_2_i'].get(token,vocab['unkTokenIdx'])
    else:
        return vocab['t_2_i'][token]

# %%
def lookUpIndex(idx):
    '''given the idx, it returns the token for that index'''
    if idx not in vocab['i_2_t']:
        raise KeyError('the index {%d} is not present' %idx)
    return vocab['i_2_t'][idx]

# %%
def vocabFromDf(df,cutoff=25):
    '''
    takes a df as an input and builds a vocabulary.
    if the number of occurences of the word is greater than the cutoff value it is qualified as token else ignore it
    '''
    initVocab()
    wordCounts = Counter()
    for r in df.review:
        for w in re.split('\W+',r):
            wordCounts[w]+=1
   
    for word,count in wordCounts.items():
        if count>=cutoff:
            addToken(word)

# %%
# build a more general vocabulary from corpus rather than a dataframe
# corpus is more general than a dataframe

def vocabFromCorpus(Corpus,cutoff=25):
    '''
    takes a df as an input and builds a vocabulary.
    if the number of occurences of the word is greater than the cutoff value it is qualified as token else ignore it
    '''
    initVocab()
    wordCounts = Counter()
    for doc in Corpus:
        for w in re.split('\W+',doc):
            wordCounts[w]+=1
   
    for word,count in wordCounts.items():
        if count>=cutoff:
            addToken(word)

# %%
# loading the data

df = pd.read_csv('dataset/reviews.csv')

# %%
vocabFromDf(df)

# %%
# first build a corpus as numpy array

X=np.asarray(df['review'])
vocabFromCorpus(X)

# %%
X
# Out:
# array(['terrible place to work for i just heard a story of them find a girl over her biological father coming in there who she hadn t seen in years she said hi to him which upset his wife and they left she finished the rest of her day working fine the next day when she went into work they fired over that situation . i for one and boycotting texas roadhouse because any place that could be that cruel to their staff does not deserve my business . . . yelp wants me to give them a star but i don t believe they deserve it',
#        ' hours , minutes total time for an extremely simple physical . stay away unless you have hours to waste ! ! ! ',
#        'my less than stellar review is for service . we waited minutes for our meals to be delivered . when we questioned the waiter , he was not helpful , so we asked to speak to the manager . the manager did not even come to speak with us ! we were loyal neighborhood customers , even walking to the restaurant frequently ! my husband then wrote an email to the owner , and it was ignored by him as well . this is obviously a business that does not value customer service , we were very disappointed and eastwind has lost regular customers',
#        ...,
#        'get the encore sandwich ! ! make sure to get it with the yogurt sauce ! ! amazing ! ! ',
#        'i m a pretty big ice cream gelato fan . pretty big . i stumbled upon angel sweet for the first time with the thanks of my handy dandy gps recommending the closest place to offer me sweet cold delicious victory . angel sweet was what popped up . n ni am pretty impressed with their selection of gelato . i typically get a fruit cream combination and haven t been disappointed as of yet . they also have a punch card to help out all those addicts . that rocks . n nmy only complaint is that the inside is rather small , and while it s cute , the chairs aren t very comfortable at all . i can never seem to stay ',
#        'where else can you find all the parts and pieces for a year old girl to become albert einstein ? they carry real theatre makeup here too which is very handy if you ever find yourself needing to go onstage . just a fun place to wander around and find crazy things for costumes and parties . '],
#       dtype=object)

# %%
vocab
# Out:
# {'t_2_i': {'<UNK>': 0,
#   'terrible': 1,
#   'place': 2,
#   'to': 3,
#   'work': 4,
#   'for': 5,
#   'i': 6,
#   'just': 7,
#   'heard': 8,
#   'a': 9,
#   'story': 10,
#   'of': 11,
#   'them': 12,
#   'find': 13,
#   'girl': 14,
#   'over': 15,
#   'her': 16,
#   'father': 17,
#   'coming': 18,
#   'in': 19,
#   'there': 20,
#   'who': 21,
#   'she': 22,
#   'hadn': 23,
#   't': 24,
#   'seen': 25,
#   'years': 26,
#   'said': 27,
#   'hi': 28,
#   'him': 29,
#   'which': 30,
#   'upset': 31,
#   'his': 32,
#   'wife': 33,
#   'and': 34,
#   'they': 35,
#   'left': 36,
#   'finished': 37,
#   'the': 38,
#   'rest': 39,
#   'day': 40,
#   'working': 41,
#   'fine': 42,
#   'next': 43,
#   'when': 44,
#   'went': 45,
#   'into': 46,
#   'fired': 47,
#   'that': 48,
#   'situation': 49,
#   'one': 50,
#   'texas': 51,
#   'roadhouse': 52,
#   'because': 53,
#   'any': 54,
#   'could': 55,
#   'be': 56,
#   'their': 57,
#   'staff': 58,
#   'does': 59,
#   'not': 60,
#   'deserve': 61,
#   'my': 62,
#   'business': 63,
#   'yelp': 64,
#   'wants': 65,
#   'me': 66,
#   'give': 67,
#   'star': 68,
#   'but': 69,
#   'don': 70,
#   'believe': 71,
#   'it': 72,
#   '': 73,
#   'hours': 74,
#   'minutes': 75,
#   'total': 76,
#   'time': 77,
#   'an': 78,
#   'extremely': 79,
#   'simple': 80,
#   'physical': 81,
#   'stay': 82,
#   'away': 83,
#   'unless': 84,
#   'you': 85,
#   'have': 86,
#   'waste': 87,
#   'less': 88,
#   'than': 89,
#   'stellar': 90,
#   'review': 91,
#   'is': 92,
#   'service': 93,
#   'we': 94,
#   'waited': 95,
#   'our': 96,
#   'meals': 97,
#   'delivered': 98,
#   'questioned': 99,
#   'waiter': 100,
#   'he': 101,
#   'was': 102,
#   'helpful': 103,
#   'so': 104,
#   'asked': 105,
#   'speak': 106,
#   'manager': 107,
#   'did': 108,
#   'even': 109,
#   'come': 110,
#   'with': 111,
#   'us': 112,
#   'were': 113,
#   'loyal': 114,
#   'neighborhood': 115,
#   'customers': 116,
#   'walking': 117,
#   'restaurant': 118,
#   'frequently': 119,
#   'husband': 120,
#   'then': 121,
#   'wrote': 122,
#   'email': 123,
#   'owner': 124,
#   'ignored': 125,
#   'by': 126,
#   'as': 127,
#   'well': 128,
#   'this': 129,
#   'obviously': 130,
#   'value': 131,
#   'customer': 132,
#   'very': 133,
#   'disappointed': 134,
#   'has': 135,
#   'lost': 136,
#   'regular': 137,
#   'm': 138,
#   's': 139,
#   'no': 140,
#   'way': 141,
#   'none': 142,
#   'n': 143,
#   'nas': 144,
#   'write': 145,
#   'door': 146,
#   'room': 147,
#   'open': 148,
#   'two': 149,
#   'gentlemen': 150,
#   'are': 151,
#   'checked': 152,
#   'going': 153,
#   'go': 154,
#   'on': 155,
#   'all': 156,
#   'evidently': 157,
#   'inn': 158,
#   'new': 159,
#   'lock': 160,
#   'system': 161,
#   'some': 162,
#   'reason': 163,
#   'impossible': 164,
#   'wait': 165,
#   'until': 166,
#   'out': 167,
#   'later': 168,
#   'today': 169,
#   'counting': 170,
#   'quiet': 171,
#   'd': 172,
#   'brought': 173,
#   'do': 174,
#   'now': 175,
#   'utterly': 176,
#   'stayed': 177,
#   'here': 178,
#   'once': 179,
#   'before': 180,
#   'loved': 181,
#   'lack': 182,
#   'concern': 183,
#   'respect': 184,
#   'sets': 185,
#   'low': 186,
#   'food': 187,
#   'mediocre': 188,
#   'at': 189,
#   'best': 190,
#   'after': 191,
#   'reading': 192,
#   'above': 193,
#   'positive': 194,
#   'reviews': 195,
#   'really': 196,
#   'great': 197,
#   'hence': 198,
#   'stars': 199,
#   'relleno': 200,
#   'soggy': 201,
#   'looked': 202,
#   'tasted': 203,
#   'like': 204,
#   'made': 205,
#   'factory': 206,
#   'guacamole': 207,
#   'decent': 208,
#   'didn': 209,
#   'care': 210,
#   'margarita': 211,
#   'mix': 212,
#   'nwe': 213,
#   'entertainment': 214,
#   'book': 215,
#   'pizza': 216,
#   'coupons': 217,
#   'came': 218,
#   'across': 219,
#   'domino': 220,
#   'twist': 221,
#   'fate': 222,
#   'since': 223,
#   'had': 224,
#   'easily': 225,
#   'pretty': 226,
#   'good': 227,
#   'coupon': 228,
#   'decided': 229,
#   'what': 230,
#   'seemed': 231,
#   'judgement': 232,
#   'would': 233,
#   'use': 234,
#   'shot': 235,
#   'nit': 236,
#   'will': 237,
#   'likely': 238,
#   'least': 239,
#   'try': 240,
#   'again': 241,
#   'npizza': 242,
#   'par': 243,
#   'those': 244,
#   'frozen': 245,
#   'ones': 246,
#   'from': 247,
#   'grocery': 248,
#   'store': 249,
#   'free': 250,
#   'sandwich': 251,
#   'shared': 252,
#   'tummy': 253,
#   'ndespite': 254,
#   'savings': 255,
#   'deal': 256,
#   'poor': 257,
#   'quality': 258,
#   'appointment': 259,
#   'months': 260,
#   'advance': 261,
#   'turned': 262,
#   'up': 263,
#   'told': 264,
#   'person': 265,
#   'quit': 266,
#   'weeks': 267,
#   'ago': 268,
#   'anyone': 269,
#   'available': 270,
#   'take': 271,
#   'attempt': 272,
#   'reschedule': 273,
#   'someone': 274,
#   'else': 275,
#   'or': 276,
#   'call': 277,
#   'cancel': 278,
#   'make': 279,
#   'things': 280,
#   'worse': 281,
#   'front': 282,
#   'desk': 283,
#   'such': 284,
#   'attitude': 285,
#   'tip': 286,
#   'beauty': 287,
#   'salon': 288,
#   'looks': 289,
#   'actually': 290,
#   'been': 291,
#   'rude': 292,
#   'women': 293,
#   'never': 294,
#   'back': 295,
#   'frankly': 296,
#   'get': 297,
#   'why': 298,
#   'people': 299,
#   'exception': 300,
#   'desert': 301,
#   'fruit': 302,
#   'cake': 303,
#   'dipped': 304,
#   'chocolate': 305,
#   'ok': 306,
#   'its': 307,
#   'alone': 308,
#   'nbut': 309,
#   'dinner': 310,
#   'overpriced': 311,
#   'overrated': 312,
#   'family': 313,
#   'friendly': 314,
#   'much': 315,
#   'better': 316,
#   'options': 317,
#   'terms': 318,
#   'thought': 319,
#   'nd': 320,
#   'chance': 321,
#   'bad': 322,
#   'idea': 323,
#   'employees': 324,
#   'feel': 325,
#   'your': 326,
#   'putting': 327,
#   'ordering': 328,
#   'if': 329,
#   'owners': 330,
#   'change': 331,
#   'quickly': 332,
#   'negative': 333,
#   'fried': 334,
#   'wontons': 335,
#   'stale': 336,
#   'awful': 337,
#   'kung': 338,
#   'pao': 339,
#   'chicken': 340,
#   'dry': 341,
#   'worth': 342,
#   'eating': 343,
#   'sun': 344,
#   'devil': 345,
#   'pork': 346,
#   'stringy': 347,
#   'filled': 348,
#   'gristle': 349,
#   'eat': 350,
#   'waitress': 351,
#   'how': 352,
#   'nothing': 353,
#   'b': 354,
#   'g': 355,
#   'refused': 356,
#   'yourself': 357,
#   'favor': 358,
#   'agree': 359,
#   'similar': 360,
#   'off': 361,
#   'bell': 362,
#   'mess': 363,
#   'stuff': 364,
#   'consignment': 365,
#   'credit': 366,
#   'return': 367,
#   'taken': 368,
#   'item': 369,
#   'big': 370,
#   'bags': 371,
#   'hardly': 372,
#   'used': 373,
#   'brand': 374,
#   'baby': 375,
#   'clothes': 376,
#   'ni': 377,
#   'bought': 378,
#   'several': 379,
#   'particular': 380,
#   'looking': 381,
#   'shoes': 382,
#   'filthy': 383,
#   'smell': 384,
#   'horrible': 385,
#   'toys': 386,
#   'missing': 387,
#   'parts': 388,
#   'grungy': 389,
#   'yet': 390,
#   'still': 391,
#   'greenway': 392,
#   'also': 393,
#   'witnessed': 394,
#   'area': 395,
#   'trash': 396,
#   'talking': 397,
#   'earlier': 398,
#   'conversation': 399,
#   'love': 400,
#   'shops': 401,
#   'kids': 402,
#   'mom': 403,
#   'learn': 404,
#   'buck': 405,
#   'stretch': 406,
#   'suggest': 407,
#   'upon': 408,
#   'child': 409,
#   'litchfield': 410,
#   'other': 411,
#   'mothers': 412,
#   'petsmart': 413,
#   'worst': 414,
#   'dog': 415,
#   'ntheir': 416,
#   'disgusting': 417,
#   'leave': 418,
#   'steel': 419,
#   'kennel': 420,
#   'themselves': 421,
#   'pay': 422,
#   'attention': 423,
#   'pup': 424,
#   'gave': 425,
#   'wrong': 426,
#   'medicine': 427,
#   'thousands': 428,
#   'vet': 429,
#   'stomach': 430,
#   'pumped': 431,
#   'trust': 432,
#   'dogs': 433,
#   'these': 434,
#   'crap': 435,
#   'shows': 436,
#   'overcharge': 437,
#   'most': 438,
#   'private': 439,
#   'places': 440,
#   'cheaper': 441,
#   'paying': 442,
#   'name': 443,
#   'having': 444,
#   'corporation': 445,
#   'behind': 446,
#   'doggie': 447,
#   'too': 448,
#   'check': 449,
#   'toss': 450,
#   'random': 451,
#   'stranger': 452,
#   'nthe': 453,
#   'grooming': 454,
#   'many': 455,
#   'screams': 456,
#   'groomers': 457,
#   'about': 458,
#   'taking': 459,
#   'either': 460,
#   'want': 461,
#   'money': 462,
#   'top': 463,
#   'package': 464,
#   'oatmeal': 465,
#   'cough': 466,
#   'bullshit': 467,
#   'shampoo': 468,
#   'lame': 469,
#   'teeth': 470,
#   'done': 471,
#   'salons': 472,
#   'vets': 473,
#   'offer': 474,
#   'services': 475,
#   'prices': 476,
#   'know': 477,
#   'tough': 478,
#   'economy': 479,
#   'important': 480,
#   'save': 481,
#   'bucks': 482,
#   'wherever': 483,
#   'whenever': 484,
#   'can': 485,
#   'every': 486,
#   'bother': 487,
#   'bring': 488,
#   'annoying': 489,
#   'll': 490,
#   'phone': 491,
#   'products': 492,
#   'items': 493,
#   'pet': 494,
#   'supply': 495,
#   'th': 496,
#   'mcdowell': 497,
#   'half': 498,
#   're': 499,
#   'something': 500,
#   'tell': 501,
#   'getting': 502,
#   'direct': 503,
#   'pee': 504,
#   'shelves': 505,
#   'stand': 506,
#   'around': 507,
#   'ignoring': 508,
#   'banfield': 509,
#   'joke': 510,
#   'wanted': 511,
#   'charge': 512,
#   'treat': 513,
#   'cats': 514,
#   'ear': 515,
#   'infection': 516,
#   'personal': 517,
#   'whatsoever': 518,
#   'shit': 519,
#   'nbottom': 520,
#   'line': 521,
#   'somewhere': 522,
#   'hundred': 523,
#   'times': 524,
#   'more': 525,
#   'professional': 526,
#   'pain': 527,
#   'dread': 528,
#   'each': 529,
#   'trip': 530,
#   'facility': 531,
#   'beat': 532,
#   'rugs': 533,
#   'stained': 534,
#   'wear': 535,
#   'flip': 536,
#   'flops': 537,
#   'towels': 538,
#   'need': 539,
#   'start': 540,
#   'first': 541,
#   'second': 542,
#   'washers': 543,
#   'expensive': 544,
#   've': 545,
#   'found': 546,
#   'city': 547,
#   'restrooms': 548,
#   'kind': 549,
#   'sends': 550,
#   'block': 551,
#   'down': 552,
#   'street': 553,
#   'coffee': 554,
#   'shop': 555,
#   'restroom': 556,
#   'last': 557,
#   'joint': 558,
#   'ate': 559,
#   'purchased': 560,
#   'groupon': 561,
#   'both': 562,
#   'enjoy': 563,
#   'greek': 564,
#   'excited': 565,
#   'lunch': 566,
#   'while': 567,
#   'definitely': 568,
#   'ordered': 569,
#   'falafel': 570,
#   'pita': 571,
#   'wasn': 572,
#   'enough': 573,
#   'help': 574,
#   'portions': 575,
#   'huge': 576,
#   'sort': 577,
#   'thing': 578,
#   'however': 579,
#   'am': 580,
#   'eater': 581,
#   'leftovers': 582,
#   'tend': 583,
#   'fridge': 584,
#   'particularly': 585,
#   'impressed': 586,
#   'nmy': 587,
#   'parmesan': 588,
#   'basically': 589,
#   'took': 590,
#   'breast': 591,
#   'threw': 592,
#   'marinara': 593,
#   'sauce': 594,
#   'little': 595,
#   'cheese': 596,
#   'served': 597,
#   'flavor': 598,
#   'seem': 599,
#   'marinated': 600,
#   'cooked': 601,
#   'interesting': 602,
#   'ton': 603,
#   'nthis': 604,
#   'enormous': 605,
#   'alright': 606,
#   'lobby': 607,
#   'nice': 608,
#   'weird': 609,
#   'under': 610,
#   'aaa': 611,
#   'government': 612,
#   'rate': 613,
#   'main': 614,
#   'ritz': 615,
#   'number': 616,
#   'literally': 617,
#   'car': 618,
#   'hotel': 619,
#   'bar': 620,
#   'common': 621,
#   'areas': 622,
#   'guests': 623,
#   'old': 624,
#   'drinks': 625,
#   'rooms': 626,
#   'vegas': 627,
#   'maybe': 628,
#   'should': 629,
#   'diagnosed': 630,
#   'dr': 631,
#   'austin': 632,
#   'always': 633,
#   'hour': 634,
#   'keep': 635,
#   'calling': 636,
#   'office': 637,
#   'results': 638,
#   'favorite': 639,
#   'ulta': 640,
#   'locations': 641,
#   'apparently': 642,
#   'general': 643,
#   'running': 644,
#   'registers': 645,
#   'tonight': 646,
#   'sure': 647,
#   'wouldn': 648,
#   'writing': 649,
#   'sooooo': 650,
#   'say': 651,
#   'hello': 652,
#   'called': 653,
#   'register': 654,
#   'st': 655,
#   'began': 656,
#   'ring': 657,
#   'pulled': 658,
#   'ultra': 659,
#   'card': 660,
#   'needed': 661,
#   'put': 662,
#   'replies': 663,
#   'walked': 664,
#   'seriously': 665,
#   'might': 666,
#   'holidays': 667,
#   'helping': 668,
#   'public': 669,
#   'think': 670,
#   'drive': 671,
#   'further': 672,
#   'chandler': 673,
#   'westin': 674,
#   'chain': 675,
#   'thus': 676,
#   'expectations': 677,
#   'case': 678,
#   'met': 679,
#   'comfortable': 680,
#   'beds': 681,
#   'unfriendly': 682,
#   'appealing': 683,
#   'double': 684,
#   'shower': 685,
#   'head': 686,
#   'nnow': 687,
#   'reasons': 688,
#   'fails': 689,
#   'relatively': 690,
#   'choice': 691,
#   'examples': 692,
#   'omelet': 693,
#   'greasy': 694,
#   'tasteless': 695,
#   'canned': 696,
#   'mushrooms': 697,
#   'breakfast': 698,
#   'buffet': 699,
#   'got': 700,
#   'typically': 701,
#   'become': 702,
#   'lukewarm': 703,
#   'choices': 704,
#   'salty': 705,
#   'e': 706,
#   'salad': 707,
#   'sandwiches': 708,
#   'burgers': 709,
#   'pancakes': 710,
#   'excellent': 711,
#   'nor': 712,
#   'hyatt': 713,
#   'location': 714,
#   'omni': 715,
#   'comparable': 716,
#   'hotels': 717,
#   'restaurants': 718,
#   'shopping': 719,
#   'attractions': 720,
#   'blocks': 721,
#   'anywhere': 722,
#   'pharmacy': 723,
#   'concierge': 724,
#   'suggestion': 725,
#   'housekeeping': 726,
#   'seems': 727,
#   'only': 728,
#   'quite': 729,
#   'vacuum': 730,
#   'cracker': 731,
#   'crumbs': 732,
#   'spilled': 733,
#   'days': 734,
#   'forget': 735,
#   'essential': 736,
#   'soap': 737,
#   'nif': 738,
#   'cheap': 739,
#   'sub': 740,
#   'per': 741,
#   'night': 742,
#   'manage': 743,
#   'charlotte': 744,
#   'terribly': 745,
#   'demand': 746,
#   'spotless': 747,
#   'sexy': 748,
#   'charming': 749,
#   'neither': 750,
#   'gas': 751,
#   'high': 752,
#   'due': 753,
#   'lake': 754,
#   'proximity': 755,
#   'being': 756,
#   'station': 757,
#   'town': 758,
#   'desperate': 759,
#   'building': 760,
#   'gary': 761,
#   'anymore': 762,
#   'same': 763,
#   'dish': 764,
#   'sometimes': 765,
#   'plate': 766,
#   'depends': 767,
#   'kitchen': 768,
#   'sales': 769,
#   'listen': 770,
#   'anything': 771,
#   'printed': 772,
#   'pictures': 773,
#   'dresses': 774,
#   'styles': 775,
#   'liked': 776,
#   'dress': 777,
#   'genuinely': 778,
#   'sorry': 779,
#   'carry': 780,
#   'size': 781,
#   'overall': 782,
#   'especially': 783,
#   'won': 784,
#   'ghetto': 785,
#   'almost': 786,
#   'walmart': 787,
#   'right': 788,
#   'base': 789,
#   'long': 790,
#   'cashiers': 791,
#   'organized': 792,
#   'constantly': 793,
#   'wandering': 794,
#   'trying': 795,
#   'rather': 796,
#   'target': 797,
#   'cause': 798,
#   'ask': 799,
#   'myself': 800,
#   'edible': 801,
#   'five': 802,
#   'dollars': 803,
#   'tortilla': 804,
#   'chips': 805,
#   'homemade': 806,
#   'salsa': 807,
#   'clearly': 808,
#   'wings': 809,
#   'fake': 810,
#   'butter': 811,
#   'rubber': 812,
#   'fault': 813,
#   'guess': 814,
#   'four': 815,
#   'pad': 816,
#   'se': 817,
#   'thai': 818,
#   'stir': 819,
#   'sweet': 820,
#   'basil': 821,
#   'sides': 822,
#   'steamed': 823,
#   'sticky': 824,
#   'rice': 825,
#   'probably': 826,
#   'recommend': 827,
#   'representation': 828,
#   'heat': 829,
#   'ours': 830,
#   'level': 831,
#   'order': 832,
#   'known': 833,
#   'usually': 834,
#   'mild': 835,
#   'medium': 836,
#   'spicy': 837,
#   'hot': 838,
#   'veggies': 839,
#   'crisp': 840,
#   'noodles': 841,
#   'egg': 842,
#   'suggests': 843,
#   'means': 844,
#   'hut': 845,
#   'ever': 846,
#   'happy': 847,
#   'tried': 848,
#   'mia': 849,
#   'march': 850,
#   'mistake': 851,
#   'life': 852,
#   'crust': 853,
#   'pepperoni': 854,
#   'complain': 855,
#   'website': 856,
#   'let': 857,
#   'equipment': 858,
#   'dirty': 859,
#   'nok': 860,
#   'forgot': 861,
#   'weekend': 862,
#   'different': 863,
#   'sale': 864,
#   'nbig': 865,
#   'problems': 866,
#   'kid': 867,
#   'saw': 868,
#   'info': 869,
#   'complained': 870,
#   'nso': 871,
#   'apologized': 872,
#   'na': 873,
#   'lady': 874,
#   'nshe': 875,
#   'sound': 876,
#   'shocked': 877,
#   'pizzas': 878,
#   'using': 879,
#   'lesser': 880,
#   'ingredients': 881,
#   'nno': 882,
#   'exact': 883,
#   'words': 884,
#   'neven': 885,
#   'thanks': 886,
#   'end': 887,
#   'past': 888,
#   'sticks': 889,
#   'experiences': 890,
#   'few': 891,
#   'ruined': 892,
#   'falling': 893,
#   'zero': 894,
#   'couple': 895,
#   'tea': 896,
#   'bread': 897,
#   'barely': 898,
#   'warm': 899,
#   'squash': 900,
#   'tortellini': 901,
#   'crispy': 902,
#   'prosciutto': 903,
#   'butternut': 904,
#   'cut': 905,
#   'nanother': 906,
#   'shrimp': 907,
#   'pasta': 908,
#   'bland': 909,
#   'adding': 910,
#   'salt': 911,
#   'pepper': 912,
#   'nwill': 913,
#   'look': 914,
#   'expect': 915,
#   'whole': 916,
#   'lot': 917,
#   'albertson': 918,
#   'mega': 919,
#   'buy': 920,
#   'month': 921,
#   'became': 922,
#   'aware': 923,
#   'carried': 924,
#   'local': 925,
#   'support': 926,
#   'badly': 927,
#   'feeling': 928,
#   'playing': 929,
#   'online': 930,
#   'blue': 931,
#   'oasis': 932,
#   'surprise': 933,
#   'company': 934,
#   'las': 935,
#   'farms': 936,
#   'surprising': 937,
#   'home': 938,
#   'san': 939,
#   'francisco': 940,
#   'fresh': 941,
#   'walk': 942,
#   'nfirst': 943,
#   'doesn': 944,
#   'sell': 945,
#   'isn': 946,
#   'worker': 947,
#   'counter': 948,
#   'offered': 949,
#   'fact': 950,
#   'heads': 951,
#   'disappointing': 952,
#   'boyfriend': 953,
#   'week': 954,
#   'pound': 955,
#   'note': 956,
#   'spent': 957,
#   'groceries': 958,
#   'otherwise': 959,
#   'department': 960,
#   'urge': 961,
#   'continue': 962,
#   'selling': 963,
#   'product': 964,
#   'rewarded': 965,
#   'impersonal': 966,
#   'response': 967,
#   'written': 968,
#   'read': 969,
#   'letter': 970,
#   'ntoday': 971,
#   'usual': 972,
#   'noticed': 973,
#   'display': 974,
#   'longer': 975,
#   'immediately': 976,
#   'clear': 977,
#   'buying': 978,
#   'arrival': 979,
#   'purpose': 980,
#   'insulting': 981,
#   'continued': 982,
#   'full': 983,
#   'price': 984,
#   'compare': 985,
#   'shipped': 986,
#   'thailand': 987,
#   'miles': 988,
#   'road': 989,
#   'promptly': 990,
#   'wonder': 991,
#   'expects': 992,
#   'sitting': 993,
#   'freezer': 994,
#   'displayed': 995,
#   'nagain': 996,
#   'realize': 997,
#   'aren': 998,
#   'may': 999,
#   ...},
#  'i_2_t': {0: '<UNK>',
#   1: 'terrible',
#   2: 'place',
#   3: 'to',
#   4: 'work',
#   5: 'for',
#   6: 'i',
#   7: 'just',
#   8: 'heard',
#   9: 'a',
#   10: 'story',
#   11: 'of',
#   12: 'them',
#   13: 'find',
#   14: 'girl',
#   15: 'over',
#   16: 'her',
#   17: 'father',
#   18: 'coming',
#   19: 'in',
#   20: 'there',
#   21: 'who',
#   22: 'she',
#   23: 'hadn',
#   24: 't',
#   25: 'seen',
#   26: 'years',
#   27: 'said',
#   28: 'hi',
#   29: 'him',
#   30: 'which',
#   31: 'upset',
#   32: 'his',
#   33: 'wife',
#   34: 'and',
#   35: 'they',
#   36: 'left',
#   37: 'finished',
#   38: 'the',
#   39: 'rest',
#   40: 'day',
#   41: 'working',
#   42: 'fine',
#   43: 'next',
#   44: 'when',
#   45: 'went',
#   46: 'into',
#   47: 'fired',
#   48: 'that',
#   49: 'situation',
#   50: 'one',
#   51: 'texas',
#   52: 'roadhouse',
#   53: 'because',
#   54: 'any',
#   55: 'could',
#   56: 'be',
#   57: 'their',
#   58: 'staff',
#   59: 'does',
#   60: 'not',
#   61: 'deserve',
#   62: 'my',
#   63: 'business',
#   64: 'yelp',
#   65: 'wants',
#   66: 'me',
#   67: 'give',
#   68: 'star',
#   69: 'but',
#   70: 'don',
#   71: 'believe',
#   72: 'it',
#   73: '',
#   74: 'hours',
#   75: 'minutes',
#   76: 'total',
#   77: 'time',
#   78: 'an',
#   79: 'extremely',
#   80: 'simple',
#   81: 'physical',
#   82: 'stay',
#   83: 'away',
#   84: 'unless',
#   85: 'you',
#   86: 'have',
#   87: 'waste',
#   88: 'less',
#   89: 'than',
#   90: 'stellar',
#   91: 'review',
#   92: 'is',
#   93: 'service',
#   94: 'we',
#   95: 'waited',
#   96: 'our',
#   97: 'meals',
#   98: 'delivered',
#   99: 'questioned',
#   100: 'waiter',
#   101: 'he',
#   102: 'was',
#   103: 'helpful',
#   104: 'so',
#   105: 'asked',
#   106: 'speak',
#   107: 'manager',
#   108: 'did',
#   109: 'even',
#   110: 'come',
#   111: 'with',
#   112: 'us',
#   113: 'were',
#   114: 'loyal',
#   115: 'neighborhood',
#   116: 'customers',
#   117: 'walking',
#   118: 'restaurant',
#   119: 'frequently',
#   120: 'husband',
#   121: 'then',
#   122: 'wrote',
#   123: 'email',
#   124: 'owner',
#   125: 'ignored',
#   126: 'by',
#   127: 'as',
#   128: 'well',
#   129: 'this',
#   130: 'obviously',
#   131: 'value',
#   132: 'customer',
#   133: 'very',
#   134: 'disappointed',
#   135: 'has',
#   136: 'lost',
#   137: 'regular',
#   138: 'm',
#   139: 's',
#   140: 'no',
#   141: 'way',
#   142: 'none',
#   143: 'n',
#   144: 'nas',
#   145: 'write',
#   146: 'door',
#   147: 'room',
#   148: 'open',
#   149: 'two',
#   150: 'gentlemen',
#   151: 'are',
#   152: 'checked',
#   153: 'going',
#   154: 'go',
#   155: 'on',
#   156: 'all',
#   157: 'evidently',
#   158: 'inn',
#   159: 'new',
#   160: 'lock',
#   161: 'system',
#   162: 'some',
#   163: 'reason',
#   164: 'impossible',
#   165: 'wait',
#   166: 'until',
#   167: 'out',
#   168: 'later',
#   169: 'today',
#   170: 'counting',
#   171: 'quiet',
#   172: 'd',
#   173: 'brought',
#   174: 'do',
#   175: 'now',
#   176: 'utterly',
#   177: 'stayed',
#   178: 'here',
#   179: 'once',
#   180: 'before',
#   181: 'loved',
#   182: 'lack',
#   183: 'concern',
#   184: 'respect',
#   185: 'sets',
#   186: 'low',
#   187: 'food',
#   188: 'mediocre',
#   189: 'at',
#   190: 'best',
#   191: 'after',
#   192: 'reading',
#   193: 'above',
#   194: 'positive',
#   195: 'reviews',
#   196: 'really',
#   197: 'great',
#   198: 'hence',
#   199: 'stars',
#   200: 'relleno',
#   201: 'soggy',
#   202: 'looked',
#   203: 'tasted',
#   204: 'like',
#   205: 'made',
#   206: 'factory',
#   207: 'guacamole',
#   208: 'decent',
#   209: 'didn',
#   210: 'care',
#   211: 'margarita',
#   212: 'mix',
#   213: 'nwe',
#   214: 'entertainment',
#   215: 'book',
#   216: 'pizza',
#   217: 'coupons',
#   218: 'came',
#   219: 'across',
#   220: 'domino',
#   221: 'twist',
#   222: 'fate',
#   223: 'since',
#   224: 'had',
#   225: 'easily',
#   226: 'pretty',
#   227: 'good',
#   228: 'coupon',
#   229: 'decided',
#   230: 'what',
#   231: 'seemed',
#   232: 'judgement',
#   233: 'would',
#   234: 'use',
#   235: 'shot',
#   236: 'nit',
#   237: 'will',
#   238: 'likely',
#   239: 'least',
#   240: 'try',
#   241: 'again',
#   242: 'npizza',
#   243: 'par',
#   244: 'those',
#   245: 'frozen',
#   246: 'ones',
#   247: 'from',
#   248: 'grocery',
#   249: 'store',
#   250: 'free',
#   251: 'sandwich',
#   252: 'shared',
#   253: 'tummy',
#   254: 'ndespite',
#   255: 'savings',
#   256: 'deal',
#   257: 'poor',
#   258: 'quality',
#   259: 'appointment',
#   260: 'months',
#   261: 'advance',
#   262: 'turned',
#   263: 'up',
#   264: 'told',
#   265: 'person',
#   266: 'quit',
#   267: 'weeks',
#   268: 'ago',
#   269: 'anyone',
#   270: 'available',
#   271: 'take',
#   272: 'attempt',
#   273: 'reschedule',
#   274: 'someone',
#   275: 'else',
#   276: 'or',
#   277: 'call',
#   278: 'cancel',
#   279: 'make',
#   280: 'things',
#   281: 'worse',
#   282: 'front',
#   283: 'desk',
#   284: 'such',
#   285: 'attitude',
#   286: 'tip',
#   287: 'beauty',
#   288: 'salon',
#   289: 'looks',
#   290: 'actually',
#   291: 'been',
#   292: 'rude',
#   293: 'women',
#   294: 'never',
#   295: 'back',
#   296: 'frankly',
#   297: 'get',
#   298: 'why',
#   299: 'people',
#   300: 'exception',
#   301: 'desert',
#   302: 'fruit',
#   303: 'cake',
#   304: 'dipped',
#   305: 'chocolate',
#   306: 'ok',
#   307: 'its',
#   308: 'alone',
#   309: 'nbut',
#   310: 'dinner',
#   311: 'overpriced',
#   312: 'overrated',
#   313: 'family',
#   314: 'friendly',
#   315: 'much',
#   316: 'better',
#   317: 'options',
#   318: 'terms',
#   319: 'thought',
#   320: 'nd',
#   321: 'chance',
#   322: 'bad',
#   323: 'idea',
#   324: 'employees',
#   325: 'feel',
#   326: 'your',
#   327: 'putting',
#   328: 'ordering',
#   329: 'if',
#   330: 'owners',
#   331: 'change',
#   332: 'quickly',
#   333: 'negative',
#   334: 'fried',
#   335: 'wontons',
#   336: 'stale',
#   337: 'awful',
#   338: 'kung',
#   339: 'pao',
#   340: 'chicken',
#   341: 'dry',
#   342: 'worth',
#   343: 'eating',
#   344: 'sun',
#   345: 'devil',
#   346: 'pork',
#   347: 'stringy',
#   348: 'filled',
#   349: 'gristle',
#   350: 'eat',
#   351: 'waitress',
#   352: 'how',
#   353: 'nothing',
#   354: 'b',
#   355: 'g',
#   356: 'refused',
#   357: 'yourself',
#   358: 'favor',
#   359: 'agree',
#   360: 'similar',
#   361: 'off',
#   362: 'bell',
#   363: 'mess',
#   364: 'stuff',
#   365: 'consignment',
#   366: 'credit',
#   367: 'return',
#   368: 'taken',
#   369: 'item',
#   370: 'big',
#   371: 'bags',
#   372: 'hardly',
#   373: 'used',
#   374: 'brand',
#   375: 'baby',
#   376: 'clothes',
#   377: 'ni',
#   378: 'bought',
#   379: 'several',
#   380: 'particular',
#   381: 'looking',
#   382: 'shoes',
#   383: 'filthy',
#   384: 'smell',
#   385: 'horrible',
#   386: 'toys',
#   387: 'missing',
#   388: 'parts',
#   389: 'grungy',
#   390: 'yet',
#   391: 'still',
#   392: 'greenway',
#   393: 'also',
#   394: 'witnessed',
#   395: 'area',
#   396: 'trash',
#   397: 'talking',
#   398: 'earlier',
#   399: 'conversation',
#   400: 'love',
#   401: 'shops',
#   402: 'kids',
#   403: 'mom',
#   404: 'learn',
#   405: 'buck',
#   406: 'stretch',
#   407: 'suggest',
#   408: 'upon',
#   409: 'child',
#   410: 'litchfield',
#   411: 'other',
#   412: 'mothers',
#   413: 'petsmart',
#   414: 'worst',
#   415: 'dog',
#   416: 'ntheir',
#   417: 'disgusting',
#   418: 'leave',
#   419: 'steel',
#   420: 'kennel',
#   421: 'themselves',
#   422: 'pay',
#   423: 'attention',
#   424: 'pup',
#   425: 'gave',
#   426: 'wrong',
#   427: 'medicine',
#   428: 'thousands',
#   429: 'vet',
#   430: 'stomach',
#   431: 'pumped',
#   432: 'trust',
#   433: 'dogs',
#   434: 'these',
#   435: 'crap',
#   436: 'shows',
#   437: 'overcharge',
#   438: 'most',
#   439: 'private',
#   440: 'places',
#   441: 'cheaper',
#   442: 'paying',
#   443: 'name',
#   444: 'having',
#   445: 'corporation',
#   446: 'behind',
#   447: 'doggie',
#   448: 'too',
#   449: 'check',
#   450: 'toss',
#   451: 'random',
#   452: 'stranger',
#   453: 'nthe',
#   454: 'grooming',
#   455: 'many',
#   456: 'screams',
#   457: 'groomers',
#   458: 'about',
#   459: 'taking',
#   460: 'either',
#   461: 'want',
#   462: 'money',
#   463: 'top',
#   464: 'package',
#   465: 'oatmeal',
#   466: 'cough',
#   467: 'bullshit',
#   468: 'shampoo',
#   469: 'lame',
#   470: 'teeth',
#   471: 'done',
#   472: 'salons',
#   473: 'vets',
#   474: 'offer',
#   475: 'services',
#   476: 'prices',
#   477: 'know',
#   478: 'tough',
#   479: 'economy',
#   480: 'important',
#   481: 'save',
#   482: 'bucks',
#   483: 'wherever',
#   484: 'whenever',
#   485: 'can',
#   486: 'every',
#   487: 'bother',
#   488: 'bring',
#   489: 'annoying',
#   490: 'll',
#   491: 'phone',
#   492: 'products',
#   493: 'items',
#   494: 'pet',
#   495: 'supply',
#   496: 'th',
#   497: 'mcdowell',
#   498: 'half',
#   499: 're',
#   500: 'something',
#   501: 'tell',
#   502: 'getting',
#   503: 'direct',
#   504: 'pee',
#   505: 'shelves',
#   506: 'stand',
#   507: 'around',
#   508: 'ignoring',
#   509: 'banfield',
#   510: 'joke',
#   511: 'wanted',
#   512: 'charge',
#   513: 'treat',
#   514: 'cats',
#   515: 'ear',
#   516: 'infection',
#   517: 'personal',
#   518: 'whatsoever',
#   519: 'shit',
#   520: 'nbottom',
#   521: 'line',
#   522: 'somewhere',
#   523: 'hundred',
#   524: 'times',
#   525: 'more',
#   526: 'professional',
#   527: 'pain',
#   528: 'dread',
#   529: 'each',
#   530: 'trip',
#   531: 'facility',
#   532: 'beat',
#   533: 'rugs',
#   534: 'stained',
#   535: 'wear',
#   536: 'flip',
#   537: 'flops',
#   538: 'towels',
#   539: 'need',
#   540: 'start',
#   541: 'first',
#   542: 'second',
#   543: 'washers',
#   544: 'expensive',
#   545: 've',
#   546: 'found',
#   547: 'city',
#   548: 'restrooms',
#   549: 'kind',
#   550: 'sends',
#   551: 'block',
#   552: 'down',
#   553: 'street',
#   554: 'coffee',
#   555: 'shop',
#   556: 'restroom',
#   557: 'last',
#   558: 'joint',
#   559: 'ate',
#   560: 'purchased',
#   561: 'groupon',
#   562: 'both',
#   563: 'enjoy',
#   564: 'greek',
#   565: 'excited',
#   566: 'lunch',
#   567: 'while',
#   568: 'definitely',
#   569: 'ordered',
#   570: 'falafel',
#   571: 'pita',
#   572: 'wasn',
#   573: 'enough',
#   574: 'help',
#   575: 'portions',
#   576: 'huge',
#   577: 'sort',
#   578: 'thing',
#   579: 'however',
#   580: 'am',
#   581: 'eater',
#   582: 'leftovers',
#   583: 'tend',
#   584: 'fridge',
#   585: 'particularly',
#   586: 'impressed',
#   587: 'nmy',
#   588: 'parmesan',
#   589: 'basically',
#   590: 'took',
#   591: 'breast',
#   592: 'threw',
#   593: 'marinara',
#   594: 'sauce',
#   595: 'little',
#   596: 'cheese',
#   597: 'served',
#   598: 'flavor',
#   599: 'seem',
#   600: 'marinated',
#   601: 'cooked',
#   602: 'interesting',
#   603: 'ton',
#   604: 'nthis',
#   605: 'enormous',
#   606: 'alright',
#   607: 'lobby',
#   608: 'nice',
#   609: 'weird',
#   610: 'under',
#   611: 'aaa',
#   612: 'government',
#   613: 'rate',
#   614: 'main',
#   615: 'ritz',
#   616: 'number',
#   617: 'literally',
#   618: 'car',
#   619: 'hotel',
#   620: 'bar',
#   621: 'common',
#   622: 'areas',
#   623: 'guests',
#   624: 'old',
#   625: 'drinks',
#   626: 'rooms',
#   627: 'vegas',
#   628: 'maybe',
#   629: 'should',
#   630: 'diagnosed',
#   631: 'dr',
#   632: 'austin',
#   633: 'always',
#   634: 'hour',
#   635: 'keep',
#   636: 'calling',
#   637: 'office',
#   638: 'results',
#   639: 'favorite',
#   640: 'ulta',
#   641: 'locations',
#   642: 'apparently',
#   643: 'general',
#   644: 'running',
#   645: 'registers',
#   646: 'tonight',
#   647: 'sure',
#   648: 'wouldn',
#   649: 'writing',
#   650: 'sooooo',
#   651: 'say',
#   652: 'hello',
#   653: 'called',
#   654: 'register',
#   655: 'st',
#   656: 'began',
#   657: 'ring',
#   658: 'pulled',
#   659: 'ultra',
#   660: 'card',
#   661: 'needed',
#   662: 'put',
#   663: 'replies',
#   664: 'walked',
#   665: 'seriously',
#   666: 'might',
#   667: 'holidays',
#   668: 'helping',
#   669: 'public',
#   670: 'think',
#   671: 'drive',
#   672: 'further',
#   673: 'chandler',
#   674: 'westin',
#   675: 'chain',
#   676: 'thus',
#   677: 'expectations',
#   678: 'case',
#   679: 'met',
#   680: 'comfortable',
#   681: 'beds',
#   682: 'unfriendly',
#   683: 'appealing',
#   684: 'double',
#   685: 'shower',
#   686: 'head',
#   687: 'nnow',
#   688: 'reasons',
#   689: 'fails',
#   690: 'relatively',
#   691: 'choice',
#   692: 'examples',
#   693: 'omelet',
#   694: 'greasy',
#   695: 'tasteless',
#   696: 'canned',
#   697: 'mushrooms',
#   698: 'breakfast',
#   699: 'buffet',
#   700: 'got',
#   701: 'typically',
#   702: 'become',
#   703: 'lukewarm',
#   704: 'choices',
#   705: 'salty',
#   706: 'e',
#   707: 'salad',
#   708: 'sandwiches',
#   709: 'burgers',
#   710: 'pancakes',
#   711: 'excellent',
#   712: 'nor',
#   713: 'hyatt',
#   714: 'location',
#   715: 'omni',
#   716: 'comparable',
#   717: 'hotels',
#   718: 'restaurants',
#   719: 'shopping',
#   720: 'attractions',
#   721: 'blocks',
#   722: 'anywhere',
#   723: 'pharmacy',
#   724: 'concierge',
#   725: 'suggestion',
#   726: 'housekeeping',
#   727: 'seems',
#   728: 'only',
#   729: 'quite',
#   730: 'vacuum',
#   731: 'cracker',
#   732: 'crumbs',
#   733: 'spilled',
#   734: 'days',
#   735: 'forget',
#   736: 'essential',
#   737: 'soap',
#   738: 'nif',
#   739: 'cheap',
#   740: 'sub',
#   741: 'per',
#   742: 'night',
#   743: 'manage',
#   744: 'charlotte',
#   745: 'terribly',
#   746: 'demand',
#   747: 'spotless',
#   748: 'sexy',
#   749: 'charming',
#   750: 'neither',
#   751: 'gas',
#   752: 'high',
#   753: 'due',
#   754: 'lake',
#   755: 'proximity',
#   756: 'being',
#   757: 'station',
#   758: 'town',
#   759: 'desperate',
#   760: 'building',
#   761: 'gary',
#   762: 'anymore',
#   763: 'same',
#   764: 'dish',
#   765: 'sometimes',
#   766: 'plate',
#   767: 'depends',
#   768: 'kitchen',
#   769: 'sales',
#   770: 'listen',
#   771: 'anything',
#   772: 'printed',
#   773: 'pictures',
#   774: 'dresses',
#   775: 'styles',
#   776: 'liked',
#   777: 'dress',
#   778: 'genuinely',
#   779: 'sorry',
#   780: 'carry',
#   781: 'size',
#   782: 'overall',
#   783: 'especially',
#   784: 'won',
#   785: 'ghetto',
#   786: 'almost',
#   787: 'walmart',
#   788: 'right',
#   789: 'base',
#   790: 'long',
#   791: 'cashiers',
#   792: 'organized',
#   793: 'constantly',
#   794: 'wandering',
#   795: 'trying',
#   796: 'rather',
#   797: 'target',
#   798: 'cause',
#   799: 'ask',
#   800: 'myself',
#   801: 'edible',
#   802: 'five',
#   803: 'dollars',
#   804: 'tortilla',
#   805: 'chips',
#   806: 'homemade',
#   807: 'salsa',
#   808: 'clearly',
#   809: 'wings',
#   810: 'fake',
#   811: 'butter',
#   812: 'rubber',
#   813: 'fault',
#   814: 'guess',
#   815: 'four',
#   816: 'pad',
#   817: 'se',
#   818: 'thai',
#   819: 'stir',
#   820: 'sweet',
#   821: 'basil',
#   822: 'sides',
#   823: 'steamed',
#   824: 'sticky',
#   825: 'rice',
#   826: 'probably',
#   827: 'recommend',
#   828: 'representation',
#   829: 'heat',
#   830: 'ours',
#   831: 'level',
#   832: 'order',
#   833: 'known',
#   834: 'usually',
#   835: 'mild',
#   836: 'medium',
#   837: 'spicy',
#   838: 'hot',
#   839: 'veggies',
#   840: 'crisp',
#   841: 'noodles',
#   842: 'egg',
#   843: 'suggests',
#   844: 'means',
#   845: 'hut',
#   846: 'ever',
#   847: 'happy',
#   848: 'tried',
#   849: 'mia',
#   850: 'march',
#   851: 'mistake',
#   852: 'life',
#   853: 'crust',
#   854: 'pepperoni',
#   855: 'complain',
#   856: 'website',
#   857: 'let',
#   858: 'equipment',
#   859: 'dirty',
#   860: 'nok',
#   861: 'forgot',
#   862: 'weekend',
#   863: 'different',
#   864: 'sale',
#   865: 'nbig',
#   866: 'problems',
#   867: 'kid',
#   868: 'saw',
#   869: 'info',
#   870: 'complained',
#   871: 'nso',
#   872: 'apologized',
#   873: 'na',
#   874: 'lady',
#   875: 'nshe',
#   876: 'sound',
#   877: 'shocked',
#   878: 'pizzas',
#   879: 'using',
#   880: 'lesser',
#   881: 'ingredients',
#   882: 'nno',
#   883: 'exact',
#   884: 'words',
#   885: 'neven',
#   886: 'thanks',
#   887: 'end',
#   888: 'past',
#   889: 'sticks',
#   890: 'experiences',
#   891: 'few',
#   892: 'ruined',
#   893: 'falling',
#   894: 'zero',
#   895: 'couple',
#   896: 'tea',
#   897: 'bread',
#   898: 'barely',
#   899: 'warm',
#   900: 'squash',
#   901: 'tortellini',
#   902: 'crispy',
#   903: 'prosciutto',
#   904: 'butternut',
#   905: 'cut',
#   906: 'nanother',
#   907: 'shrimp',
#   908: 'pasta',
#   909: 'bland',
#   910: 'adding',
#   911: 'salt',
#   912: 'pepper',
#   913: 'nwill',
#   914: 'look',
#   915: 'expect',
#   916: 'whole',
#   917: 'lot',
#   918: 'albertson',
#   919: 'mega',
#   920: 'buy',
#   921: 'month',
#   922: 'became',
#   923: 'aware',
#   924: 'carried',
#   925: 'local',
#   926: 'support',
#   927: 'badly',
#   928: 'feeling',
#   929: 'playing',
#   930: 'online',
#   931: 'blue',
#   932: 'oasis',
#   933: 'surprise',
#   934: 'company',
#   935: 'las',
#   936: 'farms',
#   937: 'surprising',
#   938: 'home',
#   939: 'san',
#   940: 'francisco',
#   941: 'fresh',
#   942: 'walk',
#   943: 'nfirst',
#   944: 'doesn',
#   945: 'sell',
#   946: 'isn',
#   947: 'worker',
#   948: 'counter',
#   949: 'offered',
#   950: 'fact',
#   951: 'heads',
#   952: 'disappointing',
#   953: 'boyfriend',
#   954: 'week',
#   955: 'pound',
#   956: 'note',
#   957: 'spent',
#   958: 'groceries',
#   959: 'otherwise',
#   960: 'department',
#   961: 'urge',
#   962: 'continue',
#   963: 'selling',
#   964: 'product',
#   965: 'rewarded',
#   966: 'impersonal',
#   967: 'response',
#   968: 'written',
#   969: 'read',
#   970: 'letter',
#   971: 'ntoday',
#   972: 'usual',
#   973: 'noticed',
#   974: 'display',
#   975: 'longer',
#   976: 'immediately',
#   977: 'clear',
#   978: 'buying',
#   979: 'arrival',
#   980: 'purpose',
#   981: 'insulting',
#   982: 'continued',
#   983: 'full',
#   984: 'price',
#   985: 'compare',
#   986: 'shipped',
#   987: 'thailand',
#   988: 'miles',
#   989: 'road',
#   990: 'promptly',
#   991: 'wonder',
#   992: 'expects',
#   993: 'sitting',
#   994: 'freezer',
#   995: 'displayed',
#   996: 'nagain',
#   997: 'realize',
#   998: 'aren',
#   999: 'may',
#   ...},
#  'unkToken': '<UNK>',
#  'unkTokenIdx': 0}

# %%
lookUpToken('the')
# Out:
# 38

# %%
lookUpIndex(38)
# Out:
# 'the'

# %%
len(vocab['t_2_i'])
# Out:
# 9123

# %% [markdown]
# ### One Hot Encoding

# %%
def oneHotVector(token,N):
    '''
    token: for which to generate one-hot vector
    N: length of the vocabulary
    '''
    oneHot = np.zeros((N,1))
    oneHot[lookUpToken(token)]=1
    return oneHot

# %%
N = len(vocab['t_2_i'])

oneHot = oneHotVector('the',N)
oneHot
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %%
oneHot[38]
# Out:
# array([1.])

# %%
## compute the feature vector of the whole document/review by taking an average
# in ML, most of the algo, every feature vector is represented as a row vector

# %%
def computeFeatureVec(doc,N):
    isFirst = True
    for token in doc:
        oneHot = oneHotVector(token,N)
        if isFirst:
            xF = oneHot
            isFirst=False
        else:
            xF = np.hstack((xF,oneHot)) # takes a lot of time 
    
    return np.mean(xF, axis=1)[:,np.newaxis]

# %%
def computeFeatureVecOpt(doc,N):
    ''' optimized version of above function '''
    fv = np.zeros(N)
    numTokens = 0
    for token in doc:
        fv[lookUpToken(token)]+=1
        numTokens+=1
    return fv/numTokens

# %%
def corpusToFeatureMatrix(Corpus,N):
    isFirstdoc = True
    for doc in Corpus:
        fV = computeFeatureVec(doc,N)
        if isFirstdoc:
            fM = fV
            isFirstdoc = False
        fM = np.hstack((fM,fV))
    return fM.T

# %%
def corpusToFeatureMatrixOpt(Corpus,N):
    fM = np.zeros((N,len(Corpus))) # predeclaring the size os faster then stacking 
    i=0
    for doc in Corpus:
        fM[:,i] = computeFeatureVecOpt(doc,N)
        i+=1
    return fM.T

# %%
X[0]
# Out:
# 'terrible place to work for i just heard a story of them find a girl over her biological father coming in there who she hadn t seen in years she said hi to him which upset his wife and they left she finished the rest of her day working fine the next day when she went into work they fired over that situation . i for one and boycotting texas roadhouse because any place that could be that cruel to their staff does not deserve my business . . . yelp wants me to give them a star but i don t believe they deserve it'

# %%
fv = computeFeatureVec(X[0], len(vocab['t_2_i']))

# %%
len(fv)
# Out:
# 9123

# %%
fv.shape
# Out:
# (9123, 1)

# %% [markdown]
# ### Train Test Split

# %%
df_new = df.copy()

# %%
df_new.head()
# Out:
#      rating                                             review
# 0  negative  terrible place to work for i just heard a stor...
# 1  negative   hours , minutes total time for an extremely s...
# 2  negative  my less than stellar review is for service . w...
# 3  negative  i m granting one star because there s no way t...
# 4  negative  the food here is mediocre at best . i went aft...

# %%
X = np.asarray(df_new['review'])
y = np.asarray(df_new['rating'])

# %%
from sklearn.model_selection import train_test_split

# %%
# 70-30 split

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,test_size=0.3, shuffle=True, random_state=42)

# %%
Xtrain
# Out:
# array(['been here before and it was way better than this last thursday ! had veggie hummus appetizer , burger that was ok , had one porter and one hefe and both were sub par , but the root beer float was the best thing i had even if i only got one scoop of ice cream . . . last time was the last time . ',
#        'why can t the attendant understand a simple direct question ? n ncan someone please tell me just where the hell i m supposed to put my freakin drink ? n nand worst of all . . . my balls don t fit in this place . n n one extra star for the bartender offering me her personal lighter n minus the extra star for not having any matches',
#        'egg drop soup is awesome ! best in phoenix . now the crab puffs had nothing but cream cheese . . . i literally broke it open to search for the meat and i didn t find any so that was very disappointing . i had the house plate for my entr u e e . the taste was ok . . . but what really killed it for me was the texture . . . it felt as though the ingredients had been soaking in a pot for days . . . it was soooo slimy . . . i couldn t eat it . . . so i just enjoyed my fried rice and egg drop soup . . . i would come here again only for the soup . . . . and i wouldn t go out of my way to make it here . ',
#        ...,
#        'just finished my first class here and i was pleasantly surprised ! i was nervous about trying a different studio i normally practice at bikram yoga institute but i bought the groupon for byp , but i was totally comfortable and felt that the class was not only really similar , but the room smelled a lot better ! njulie was my instructor today and she was sweet and helpful and made sure i was okay since i was a new student here . i had a great class and am looking forward to my month long package ! ',
#        'hmm . just a typical b n , but where i get annoyed is with the cashier trying to guilt me into buying their membership . years ago i did the math on this thing and by paying year to get a discount you d have to spend year to break even . i don t spend year at b n . now , i think they ve made some changes where you can get more of a discount than that on the nd tuesday in august of a leap year or something . n nhowever , i m more of an indie or used bookstore or library kinda gal . but , i really overall have nothing against b n . once in awhile i ll stop in and raid the newsstand , which always has a good selection of materials for me to read when i m procrastinating doing something else . n nso on monday i find my way to the cashier with my random stack of reading materials and the cashier asks me twice if i want their membership . both times i politely said , no , that s ok . then she says , looking at me sideways , you know , some people add up how much they spend every year here and are shocked and disappointed when they figure out how they could have benefited from the discount . n ntick tick tick n nyou know what . . . . . n nthat passive aggressive b . s . really turned me off . i ll get my magazines elsewhere . ',
#        'came in to have glasses repaired . ended up with cosmetic damage on the exterior of the frames . these are frames . repair tech offered off , but frames are still damaged . did not make the customer whole after ruining the cosmetics of the frame . will not repeat business here . beware of the condition of your sunglasses before you drop them off . . . they will surely come out in a much different condition after they are fixed . '],
#       dtype=object)

# %%
# we build the vocabulary from the train data as we assume we have never seen the test data

# %%
vocabFromCorpus(Xtrain)

# %%
# function to return entire feature matrix for the classificaiton algorithm

# %%
N = len(vocab['t_2_i'])

Xtrain_fM = corpusToFeatureMatrixOpt(Xtrain,N)
Xtest_fM = corpusToFeatureMatrixOpt(Xtest,N)

# %%
Xtrain_fM.shape
# Out:
# (39200, 7507)

# %%
Xtest_fM.shape
# Out:
# (16800, 7507)

# %% [markdown]
# ### Training the MOdel

# %%
from sklearn.linear_model import LogisticRegression as LR
from sklearn.metrics import confusion_matrix

import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
M = LR().fit(Xtrain_fM,ytrain)

# %%
y_pred = M.predict(Xtest_fM)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d515f578098c> in <module>
# ----> 1 y_pred = M.predict(X_)
#
# NameError: name 'M' is not defined

# %%
mat = confusion_matrix(ytest,y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False, xticklabels = np.unique(y), yticklabels = np.unique(y))
plt.xlabel('True Label')
plt.ylabel('Predicted Label')
